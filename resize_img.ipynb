# %%
from PIL import Image
import os
save_dir = "./resized_img"
os.makedirs(save_dir, exist_ok=True)

img = Image.open(r"D:\GitHub\MobileIE\datasets\uieb\test\input\9567.png")
img = img.resize((640, 480))
filename = "uieb-input-9567.png"
img.save(os.path.join(save_dir, filename))
